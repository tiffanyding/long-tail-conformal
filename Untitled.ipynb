# %%
import pickle

from utils.experiment_utils import *

# %%
outputs_folder = get_outputs_folder()
pth = f'{outputs_folder}/plantnet-trunc_softmax_alpha=0.1_rc3p.pkl'

# %%
with open(pth, 'rb') as f:
    res = pickle.load(f)

# %%
res
# Out:
# {'qhats': array([9.76217584e-01, 9.18002168e-01, 5.86564521e-01, 2.99856158e-01,
#                    inf, 9.10749203e-01, 2.57253723e-01,            inf,
#         4.87005782e-01, 6.33137322e-01, 9.72236039e-01, 7.47003160e-01,
#         4.32635156e-01,            inf, 5.01339090e-01, 9.85187440e-01,
#         6.08158258e-01, 9.98509286e-01,            inf, 5.98889680e-02,
#         9.78642381e-02, 9.79349756e-01,            inf, 6.02515339e-01,
#         7.23005313e-01,            inf, 8.88690674e-01,            inf,
#         5.69773231e-01, 9.81229932e-01, 8.50606806e-01, 8.91229527e-01,
#                    inf, 8.48373772e-01, 9.86128186e-01,            inf,
#         8.39538877e-01, 9.80959000e-01,            inf, 7.59209465e-01,
#         1.87105942e-01,            inf, 9.99539165e-01,            inf,
#                    inf, 9.05643650e-01, 5.86631600e-01, 6.29663455e-01,
#         4.90559343e-01, 9.49746374e-01, 5.20758323e-01,            inf,
# ...
